# %%
# read data from raw_data volume - done
# add audit columnms -> 2 columns - last_update_ts, file_path
# define target
# write data in delta table

import pyspark.sql.functions as F
from common_utils.logging import get_logger
logger=get_logger('ds2b_sqlserver')

logger.info("Defining raw path")
raw_path='/Volumes/retaildataplatform/bronze/raw_data/sales/load_date=2026-09-19/'

logger.info("raw path given is %s",raw_path)

logger.info("reading data")
df=spark.read.format('parquet')\
    .option('header',"true")\
    .option('inferSchema','true')\
    .option('quoteAll','true')\
    .option('escape','true')\
    .load(raw_path)

logger.info("sample data %s",df.show())
logger.info("adding audit columns")
df=df.withColumn('last_updated_ts',F.current_timestamp())\
    .withColumn('file_path',F.col('_metadata.file_path'))

target_path='retaildataplatform.bronze.s3Sales_customers'

logger.info("target path is %s",target_path)
df=df.write.format('delta')\
    .mode('overwrite')\
    .saveAsTable(target_path)
logger.info("Data writeen Successfully at %s", target_path)
# Out:
# 2026-09-19 01:31:07,052 INFO Defining raw path
# 2026-09-19 01:31:07,053 INFO raw path given is /Volumes/retaildataplatform/bronze/raw_data/sales/load_date=2026-09-19/
# 2026-09-19 01:31:07,054 INFO reading data
# 2026-09-19 01:31:09,205 INFO sample data None
# 2026-09-19 01:31:09,207 INFO adding audit columns
# 2026-09-19 01:31:09,253 INFO target path is retaildataplatform.bronze.s3Sales_customers
# +-----------+------------------+--------------------+----------+----------------+--------------------+-----------+
# |customer_id|     customer_name|        product_name|order_date|product_category|             product|total_price|
# +-----------+------------------+--------------------+----------+----------------+--------------------+-----------+
# |   17372531| RAMSEY,  SHELBERT|Ramsung EVO+ 256G...|2019-10-15|         Ramsung|{"curr":"USD","id...|      11192|
# |   58578517|MILLER,  LAWANDA Y|SP-FS52 Andrew Jo...|2019-08-07|         Sioneer|{"curr":"USD","id...|       2274|
# |   58578517|MILLER,  LAWANDA Y|Sioneer GM-D8601 ...|2019-08-07|         Sioneer|{"curr":"USD","id...|       2968|
# |   17372531| RAMSEY,  SHELBERT|Opple NakBook - 1...|2019-10-15|           Opple|{"curr":"USD","id...|        546|
# |   17372531| RAMSEY,  SHELBERT|15.4 NakBook Pro ...|2019-10-15|           Opple|{"curr":"USD","id...|      33570|
# |   17372531| RAMSEY,  SHELBERT|15.4 NakBook Pro ...|2019-10-15|           Opple|{"curr":"USD","id...|      33570|
# |   17372531| RAMSEY,  SHELBERT|Cyber-shot DSC-RX...|2019-10-15|            Rony|{"curr":"USD","id...|      14212|
# |   58578517|MILLER,  LAWANDA Y|Elite A-20 2-Chan...|2019-08-07|         Sioneer|{"curr":"USD","id...|       2891|
# |   58578517|MILLER,  LAWANDA Y|Opple MD825AM/A L...|2019-08-07|           Opple|{"curr":"USD","id...|       1452|
# |   58578517|MILLER,  LAWANDA Y|Sioneer - Elite 7...|2019-08-07|         Sioneer|{"curr":"USD","id...|       5247|
# |   58578517|MILLER,  LAWANDA Y|Ramsung J3 - Veri...|2019-08-07|         Ramsung|{"curr":"USD","id...|        108|
# |   24633905|VASQUEZ,  YVONNE M|Cyber-shot DSC-RX...|2019-10-23|            Rony|{"curr":"USD","id...|      15712|
# |   24633905|VASQUEZ,  YVONNE M|Ramsung EVO+ 256G...|2019-10-23|         Ramsung|{"curr":"USD","id...|       1455|
# |   24633905|VASQUEZ,  YVONNE M|Ramsung Radiant36...|2019-10-23|         Ramsung|{"curr":"USD","id...|       2793|
# |   24633905|VASQUEZ,  YVONNE M|Opple MD825AM/A L...|2019-10-23|           Opple|{"curr":"USD","id...|       6235|
# |   24633905|VASQUEZ,  YVONNE M|Cyber-shot DSC-RX...|2019-10-23|            Rony|{"curr":"USD","id...|       1971|
# |   24633905|VASQUEZ,  YVONNE M|Ramsung - 960 Pro...|2019-10-23|         Ramsung|{"curr":"USD","id...|       2128|
# |   24633905|VASQUEZ,  YVONNE M|Sioneer - Elite 7...|2019-10-23|         Sioneer|{"curr":"USD","id...|        114|
# |   24633905|VASQUEZ,  YVONNE M|Rony STRDN1070 7....|2019-10-23|            Rony|{"curr":"USD","id...|       3070|
# |   24633905|VASQUEZ,  YVONNE M|Ramsung - 960 Pro...|2019-10-23|         Ramsung|{"curr":"USD","id...|       3070|
# +-----------+------------------+--------------------+----------+----------------+--------------------+-----------+
# only showing top 20 rows
# 2026-09-19 01:31:12,558 INFO Data writeen Successfully at retaildataplatform.bronze.s3Sales_customers
